# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyamThapliyal07/Projects/blob/main/Ev_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("/content/electric_vehicles_spec_2025.csv.csv")

# %%
df.head()
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion              NaN      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# brand                          0
# model                          1
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               1
# towing_capacity_kg            26
# cargo_volume_l                 1
# seats                          0
# drivetrain                     0
# segment                        0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# source_url                     0
# dtype: int64

# %%
df.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     478.000000            478.000000       276.000000   471.000000
# mean      185.487448             74.043724       485.293478   498.012739
# std        34.252773             20.331058      1210.819733   241.461128
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       150.000000   305.000000
# 50%       180.000000             76.150000       216.000000   430.000000
# 75%       201.000000             90.600000       324.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            478.000000  478.000000            478.000000
# mean             162.903766  393.179916              6.882636
# std               34.317532  103.287335              2.730696
# ...

# %%
columns=['brand', 'model', 'top_speed_kmh', 'battery_capacity_kWh',
       'battery_type', 'number_of_cells', 'torque_nm', 'efficiency_wh_per_km',
       'range_km', 'acceleration_0_100_s', 'fast_charging_power_kw_dc',
       'fast_charge_port', 'towing_capacity_kg', 'cargo_volume_l', 'seats',
       'drivetrain', 'segment', 'length_mm', 'width_mm', 'height_mm',
       'car_body_type', 'source_url']

# %%
def show_plots(df):
  for i, col in enumerate(columns):
    if df[col].dtype=="int64" or df[col].dtype=="float64":
      plt.figure(figsize=(10,5))
      plt.subplot(4,5,i+1)
      sns.boxplot(df[col])
  plt.tight_layout()
  plt.show()

# %%
show_plots(df)

# %%
def cap_outliers_iqr(df, column):
  q1= df[column].quantile(0.25)
  q2= df[column].quantile(0.75)
  iqr= q2-q1
  Lower_bound= q1-1.5*iqr
  Upper_bound=q2+1.5*iqr

  df[column]=df[column].apply(lambda x: Upper_bound if x>Upper_bound else x)
  return df

# %%
cap_outliers_iqr(df, 'torque_nm')
cap_outliers_iqr(df, 'top_speed_kmh')
cap_outliers_iqr(df, 'battery_capacity_kWh')
cap_outliers_iqr(df, 'number_of_cells')
cap_outliers_iqr(df, 'efficiency_wh_per_km')
cap_outliers_iqr(df, 'range_km')
cap_outliers_iqr(df, 'acceleration_0_100_s')
cap_outliers_iqr(df, 'fast_charging_power_kw_dc')
cap_outliers_iqr(df, 'towing_capacity_kg')
cap_outliers_iqr(df, 'seats')
cap_outliers_iqr(df, 'length_mm')
cap_outliers_iqr(df, 'width_mm')
cap_outliers_iqr(df, 'height_mm')
# Out:
#        brand                    model  top_speed_kmh  battery_capacity_kWh  \
# 0     Abarth         500e Convertible          155.0                  37.8
# 1     Abarth           500e Hatchback          155.0                  37.8
# 2     Abarth      600e Scorpionissima          200.0                  50.8
# 3     Abarth             600e Turismo          200.0                  50.8
# 4     Aiways                       U5          150.0                  60.0
# ..       ...                      ...            ...                   ...
# 473    Zeekr           7X Premium RWD          210.0                  71.0
# 474    Zeekr        X Core RWD (MY25)          190.0                  49.0
# 475    Zeekr  X Long Range RWD (MY25)          190.0                  65.0
# 476    Zeekr   X Privilege AWD (MY25)          190.0                  65.0
# 477  firefly                      NaN          150.0                  41.2
#
# ...

# %%
show_plots(df)

# %%
df.isnull().sum()
# Out:
# brand                          0
# model                          1
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               1
# towing_capacity_kg            26
# cargo_volume_l                 1
# seats                          0
# drivetrain                     0
# segment                        0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# source_url                     0
# dtype: int64

# %%
df["number_of_cells"]=df["number_of_cells"].fillna(df["number_of_cells"].mean())

# %%
df["torque_nm"]=df["torque_nm"].fillna(df["torque_nm"].mean())

# %%
df["fast_charging_power_kw_dc"]=df["fast_charging_power_kw_dc"].fillna(df["fast_charging_power_kw_dc"])

# %%
df["fast_charge_port"]=df["fast_charge_port"].fillna(df["fast_charge_port"].mode())

# %%
df['towing_capacity_kg'] = df['towing_capacity_kg'].fillna(df['towing_capacity_kg'].mean())


df['cargo_volume_l'] = df['cargo_volume_l'].fillna('Unknown')
df['fast_charge_port'] = df['fast_charge_port'].fillna('Unknown')
df['fast_charging_power_kw_dc'] = df['fast_charging_power_kw_dc'].fillna(df['fast_charging_power_kw_dc'].mean())

# %%
df.isnull().sum()
# Out:
# brand                        0
# model                        1
# top_speed_kmh                0
# battery_capacity_kWh         0
# battery_type                 0
# number_of_cells              0
# torque_nm                    0
# efficiency_wh_per_km         0
# range_km                     0
# acceleration_0_100_s         0
# fast_charging_power_kw_dc    0
# fast_charge_port             0
# towing_capacity_kg           0
# cargo_volume_l               0
# seats                        0
# drivetrain                   0
# segment                      0
# length_mm                    0
# width_mm                     0
# height_mm                    0
# car_body_type                0
# source_url                   0
# dtype: int64

# %%
sns.histplot(data=df, x=df["range_km"], kde=True, color="red")
plt.show()

# %%
brand_count= df["brand"].value_counts().head(10)

# %%
brand_count.head(10)
# Out:
# brand
# Mercedes-Benz    42
# Audi             28
# Porsche          26
# Volkswagen       23
# Ford             22
# BMW              20
# Peugeot          19
# Volvo            18
# BYD              17
# Smart            17
# Name: count, dtype: int64

# %%
sns.barplot(x=brand_count.index, y=brand_count.values, color="violet")
plt.xticks(rotation=90, ha="right")
plt.show()

# %%
sns.scatterplot(data=df, x="battery_capacity_kWh", y="range_km", color="red" )
plt.show()

# %%
brand_avg_range= df.groupby("brand")[["range_km"]].mean()
brand_avg_range
# Out:
#                  range_km
# brand
# Abarth         252.500000
# Aiways         332.500000
# Alfa           315.000000
# Alpine         307.500000
# Audi           478.392857
# BMW            458.250000
# BYD            350.882353
# CUPRA          431.000000
# Cadillac       460.000000
# Citroen        256.250000
# DS             433.000000
# Dacia          162.500000
# Dongfeng       222.500000
# Elaris         390.000000
# Fiat           209.375000
# Ford           368.636364
# GWM            342.500000
# Genesis        383.000000
# Honda          335.000000
# Hongqi         381.666667
# Hyundai        400.714286
# Jaguar         380.000000
# Jeep           340.000000
# KGM            370.000000
# Kia            408.750000
# Lancia         310.000000
# Leapmotor      287.500000
# Lexus          351.666667
# Lotus          489.166667
# Lucid          603.333333
# Lynk&Co        370.000000
# MG             341.666667
# Maserati       405.000000
# Maxus          365.000000
# ...

# %%
brand_avg_range.head(10).sort_values(by='range_km', ascending= False)
# Out:
#             range_km
# brand
# Audi      478.392857
# Cadillac  460.000000
# BMW       458.250000
# CUPRA     431.000000
# BYD       350.882353
# Aiways    332.500000
# Alfa      315.000000
# Alpine    307.500000
# Citroen   256.250000
# Abarth    252.500000

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=brand_avg_range.index, y=brand_avg_range['range_km'], color="violet")
plt.xticks(rotation=90, ha="right")
plt.show()

# %%
efficiency_analysis = df.groupby('segment').agg({
    'battery_capacity_kWh': 'mean',
    'efficiency_wh_per_km': 'mean',
    'range_km': 'mean'
}).round(2)

# %%
efficiency_analysis
# Out:
#                    battery_capacity_kWh  efficiency_wh_per_km  range_km
# segment
# A - Mini                          28.67                119.67    183.33
# B - Compact                       40.47                129.31    252.24
# C - Medium                        59.14                137.09    355.00
# D - Large                         73.43                143.54    447.86
# E - Executive                     85.92                162.93    478.50
# F - Luxury                        96.59                176.18    525.00
# G - Sports                        74.40                157.00    410.00
# I - Luxury                       102.00                192.00    465.00
# JA - Mini                         42.50                121.50    277.50
# JB - Compact                      54.43                141.93    307.16
# JC - Medium                       70.85                152.71    389.34
# JD - Large                        84.58                163.71    430.34
# ...

# %%
segments=df["segment"].unique()

# %%
for i, segment in enumerate(segments):
  segment_data= df[df["segment"]==segment]
  plt.figure(figsize=(10,20))
  plt.subplot(4,2,i+1)
  sns.scatterplot(x=segment_data["battery_capacity_kWh"], y=segment_data["efficiency_wh_per_km"], color="red")
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-64-1213419931.py in <cell line: 0>()
#       2   segment_data= df[df["segment"]==segment]
#       3   plt.figure(figsize=(10,20))
# ----> 4   plt.subplot(4,2,i+1)
#       5   sns.scatterplot(x=segment_data["battery_capacity_kWh"], y=segment_data["efficiency_wh_per_km"], color="red")
#       6   plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1548
#    1549     # First, search for an existing subplot with a matching spec.
# -> 1550     key = SubplotSpec._from_subplot_args(fig, args)
#    1551
#    1552     for ax in fig.axes:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     587         else:
#     588             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# ...

# %%
sns.barplot(x=efficiency_analysis.index, y=efficiency_analysis["efficiency_wh_per_km"], color="violet")
plt.xticks(rotation=90, ha="right")
plt.show()

# %%
segment_count= df["segment"].value_counts()

# %%
segment_count
# Out:
# segment
# JC - Medium          91
# JD - Large           58
# F - Luxury           51
# N - Passenger Van    47
# JB - Compact         44
# C - Medium           34
# E - Executive        30
# JF - Luxury          30
# B - Compact          29
# D - Large            28
# JE - Executive       28
# A - Mini              3
# JA - Mini             2
# G - Sports            2
# I - Luxury            1
# Name: count, dtype: int64

# %%
sns.barplot(x=segment_count.index, y=segment_count.values, color="green")
plt.xticks(rotation=90, ha="right")
plt.show()

# %%
segment_analysis= df.groupby("segment").agg({
    "battery_capacity_kWh": ["mean","max","min"],
    "range_km": ["mean","max","min"],
    "efficiency_wh_per_km": ["mean","max","min"]
}).round(2)

# %%
segment_analysis
# Out:
#                   battery_capacity_kWh               range_km            \
#                                   mean    max    min     mean  max  min
# segment
# A - Mini                         28.67   36.0   25.0   183.33  225  160
# B - Compact                      40.47   52.0   21.3   252.24  330  135
# C - Medium                       59.14   79.0   44.9   355.00  495  260
# D - Large                        73.43   85.0   50.0   447.86  565  320
# E - Executive                    85.92   96.0   73.5   478.50  555  400
# F - Luxury                       96.59  118.0   73.5   525.00  685  395
# G - Sports                       74.40   74.4   74.4   410.00  425  395
# I - Luxury                      102.00  102.0  102.0   465.00  465  465
# JA - Mini                        42.50   46.0   39.0   277.50  300  255
# JB - Compact                     54.43   78.0   38.5   307.16  455  230
# JC - Medium                      70.85   96.9   47.1   389.34  500  275
# ...

# %%
sns.histplot(data=segment_analysis, x=segment_analysis["battery_capacity_kWh"]["mean"], kde=True, color="red")
plt.show()

# %%
sns.scatterplot(data=df, x=df["battery_capacity_kWh"], y=df['fast_charging_power_kw_dc'], color="green")
plt.show()

# %%
sns.barplot(x=segment_analysis.index, y=segment_analysis["battery_capacity_kWh"]["mean"], color="violet")
plt.xticks(rotation=90, ha="right")
plt.show()
